# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt

# Manually specifying column names
column_names = ['Gender', 'Age', 'Type of Injury', 'Area', 'Type of Vehicle', '2020', '2021', '2022']

# Try using 'ISO-8859-1' or 'latin1' encoding
Dataset = pd.read_csv('C:/Users/kaspe/Documents/GitHub/KCL_Eksamensprojekt/AI_Model_Training/data/20244281821457313338UHELDK129906013912.csv', names=column_names, sep=';', encoding='ISO-8859-1')

df = Dataset
df.head()
# Out:
#   Gender      Age     Type of Injury                Area  \
# 0   Mænd  0-17 år  Personskade i alt  Region Hovedstaden
# 1   Mænd  0-17 år  Personskade i alt  Region Hovedstaden
# 2   Mænd  0-17 år  Personskade i alt  Region Hovedstaden
# 3   Mænd  0-17 år  Personskade i alt  Region Hovedstaden
# 4   Mænd  0-17 år  Personskade i alt  Region Hovedstaden
#
#                       Type of Vehicle  2020  2021  2022
# 0                Almindelig personbil     9     7     4
# 1                                Taxi     0     0     0
# 2  Køretøj 0-3.500 kg under udrykning     0     0     0
# 3                 Varebil 0-3.500 kg.     0     1     0
# 4              Lastbil over 3.500 kg.     0     0     0

# %%
# Proceed with the data preparation

# Merge 'Knallert' and 'Knallert 45' into 'Knallert'
df['Type of Vehicle'] = df['Type of Vehicle'].replace(['Knallert 45'], 'Knallert')

# Sum the incidents from 2020, 2021, 2022 into a single 'Total Incidents' column
df['Total Incidents'] = df[['2020', '2021', '2022']].sum(axis=1)

# Drop the now unnecessary year columns, since we have total incidents
df.drop(['2020', '2021', '2022'], axis=1, inplace=True)

# Filter out rows where 'Type of Injury' equals 'Personskade i alt'
df = df[df['Type of Injury'] != 'Personskade i alt']

# Create a copy of the dataframe for encoding
df_encoded = df.copy()

# Initialize a label encoder for each categorical column
label_encoders = {}
for column in ['Gender', 'Age', 'Type of Injury', 'Area', 'Type of Vehicle']:
    le = LabelEncoder()
    df_encoded[column] = le.fit_transform(df_encoded[column])
    label_encoders[column] = le

# Now, `df_encoded` contains integers instead of string categories

# %%
df.head()
# Out:
#    Gender      Age Type of Injury                Area  \
# 60   Mænd  0-17 år         Dræbte  Region Hovedstaden
# 61   Mænd  0-17 år         Dræbte  Region Hovedstaden
# 62   Mænd  0-17 år         Dræbte  Region Hovedstaden
# 63   Mænd  0-17 år         Dræbte  Region Hovedstaden
# 64   Mænd  0-17 år         Dræbte  Region Hovedstaden
#
#                        Type of Vehicle  Total Incidents
# 60                Almindelig personbil                2
# 61                                Taxi                0
# 62  Køretøj 0-3.500 kg under udrykning                0
# 63                 Varebil 0-3.500 kg.                0
# 64              Lastbil over 3.500 kg.                0

# %%
df_encoded
# Out:
#       Gender  Age  Type of Injury  Area  Type of Vehicle  Total Incidents
# 60         1    0               1     0                0                2
# 61         1    0               1     0                9                0
# 62         1    0               1     0                6                0
# 63         1    0               1     0               10                0
# 64         1    0               1     0                7                0
# ...      ...  ...             ...   ...              ...              ...
# 4315       2    5               2     2                5                0
# 4316       2    5               2     2                5                0
# 4317       2    5               2     2                3                0
# 4318       2    5               2     2                4                0
# 4319       2    5               2     2                1                0
#
# [3240 rows x 6 columns]

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
import math

# Preparing the data
X = df_encoded.drop(['Type of Injury', 'Total Incidents'], axis=1)
y = df_encoded['Type of Injury']
y = to_categorical(y)

# Define sample weights based on 'Total Incidents'
sample_weights = df_encoded['Total Incidents']

# Split the data, ensuring weights are split correspondingly
X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, sample_weights, test_size=0.2, random_state=42)

def step_decay(epoch):
    initial_lrate = 0.01
    drop = 0.5
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

lrate = LearningRateScheduler(step_decay)

model = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(y_train.shape[1], activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'],
              weighted_metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    sample_weight=weights_train,
                    epochs=100,
                    batch_size=10,
                    validation_split=0.1,
                    callbacks=[lrate])




# Evaluate the model on the test data
loss, accuracy, weighted_accuracy = model.evaluate(X_test, y_test, sample_weight=weights_test)  # Including sample weights here as well

# Now print both accuracies
print(f"Test Unweighted Accuracy: {accuracy*100:.2f}%")
print(f"Test Weighted Accuracy: {weighted_accuracy*100:.2f}%")
# Out:
# Epoch 1/100
# C:\Users\kaspe\AppData\Roaming\Python\Python310\site-packages\keras\src\engine\data_adapter.py:1798: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 234/234 [==============================] - 1s 2ms/step - loss: 2.6567 - accuracy: 0.3203 - weighted_accuracy: 0.4518 - val_loss: 1.2720 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0100
# Epoch 2/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.4239 - accuracy: 0.3255 - weighted_accuracy: 0.5706 - val_loss: 1.2758 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0100
# Epoch 3/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.3278 - accuracy: 0.3280 - weighted_accuracy: 0.5613 - val_loss: 1.3232 - val_accuracy: 0.3462 - val_weighted_accuracy: 0.5149 - lr: 0.0100
# Epoch 4/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.4137 - accuracy: 0.3246 - weighted_accuracy: 0.5524 - val_loss: 1.2191 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0100
# Epoch 5/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2856 - accuracy: 0.3276 - weighted_accuracy: 0.5788 - val_loss: 1.2146 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0100
# Epoch 6/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2813 - accuracy: 0.3255 - weighted_accuracy: 0.5654 - val_loss: 1.2724 - val_accuracy: 0.3385 - val_weighted_accuracy: 0.6188 - lr: 0.0100
# Epoch 7/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2717 - accuracy: 0.3263 - weighted_accuracy: 0.5865 - val_loss: 1.1741 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0100
# Epoch 8/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2595 - accuracy: 0.3289 - weighted_accuracy: 0.5860 - val_loss: 1.1781 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0100
# Epoch 9/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2779 - accuracy: 0.3250 - weighted_accuracy: 0.5726 - val_loss: 1.2639 - val_accuracy: 0.3423 - val_weighted_accuracy: 0.6287 - lr: 0.0100
# Epoch 10/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.3156 - accuracy: 0.3310 - weighted_accuracy: 0.5963 - val_loss: 1.1916 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 11/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2365 - accuracy: 0.3255 - weighted_accuracy: 0.5654 - val_loss: 1.2276 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 12/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2554 - accuracy: 0.3285 - weighted_accuracy: 0.5865 - val_loss: 1.2063 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 13/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2509 - accuracy: 0.3272 - weighted_accuracy: 0.5833 - val_loss: 1.1967 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 14/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2364 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2051 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 15/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2587 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.1937 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 16/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2706 - accuracy: 0.3276 - weighted_accuracy: 0.5844 - val_loss: 1.1935 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 17/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2529 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.1998 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 18/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2477 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2051 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 19/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2412 - accuracy: 0.3293 - weighted_accuracy: 0.5851 - val_loss: 1.1930 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0050
# Epoch 20/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2377 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.1946 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 21/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2416 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.1966 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 22/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2422 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.1968 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 23/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2401 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.1973 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 24/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2368 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2017 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 25/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2420 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2024 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 26/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2369 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2054 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 27/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2385 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.1960 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 28/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2523 - accuracy: 0.3276 - weighted_accuracy: 0.5790 - val_loss: 1.2040 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 29/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2411 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2030 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0025
# Epoch 30/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2409 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2031 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 31/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2372 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2022 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 32/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2414 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2054 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 33/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2371 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2026 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 34/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2356 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2058 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 35/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2347 - accuracy: 0.3276 - weighted_accuracy: 0.5790 - val_loss: 1.1988 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 36/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2402 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2012 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 37/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2387 - accuracy: 0.3285 - weighted_accuracy: 0.5769 - val_loss: 1.2062 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 38/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2282 - accuracy: 0.3285 - weighted_accuracy: 0.5844 - val_loss: 1.2080 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 39/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2271 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2097 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 0.0012
# Epoch 40/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2171 - accuracy: 0.3280 - weighted_accuracy: 0.5844 - val_loss: 1.2156 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 41/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2411 - accuracy: 0.3280 - weighted_accuracy: 0.5812 - val_loss: 1.2133 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 42/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2234 - accuracy: 0.3289 - weighted_accuracy: 0.5905 - val_loss: 1.2210 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 43/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2250 - accuracy: 0.3280 - weighted_accuracy: 0.5864 - val_loss: 1.2220 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 44/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2348 - accuracy: 0.3276 - weighted_accuracy: 0.5812 - val_loss: 1.2169 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 45/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2215 - accuracy: 0.3280 - weighted_accuracy: 0.5902 - val_loss: 1.2189 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 46/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.1965 - accuracy: 0.3298 - weighted_accuracy: 0.6026 - val_loss: 1.2254 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 47/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2195 - accuracy: 0.3280 - weighted_accuracy: 0.5939 - val_loss: 1.2289 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 48/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2557 - accuracy: 0.3280 - weighted_accuracy: 0.5822 - val_loss: 1.2246 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 49/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2375 - accuracy: 0.3285 - weighted_accuracy: 0.5825 - val_loss: 1.2264 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 6.2500e-04
# Epoch 50/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2279 - accuracy: 0.3280 - weighted_accuracy: 0.5824 - val_loss: 1.2265 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 51/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2319 - accuracy: 0.3285 - weighted_accuracy: 0.5854 - val_loss: 1.2264 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 52/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2075 - accuracy: 0.3289 - weighted_accuracy: 0.5955 - val_loss: 1.2315 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 53/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2394 - accuracy: 0.3280 - weighted_accuracy: 0.5820 - val_loss: 1.2324 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 54/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2100 - accuracy: 0.3315 - weighted_accuracy: 0.5995 - val_loss: 1.2354 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 55/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2298 - accuracy: 0.3293 - weighted_accuracy: 0.6008 - val_loss: 1.2395 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 56/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2384 - accuracy: 0.3276 - weighted_accuracy: 0.5918 - val_loss: 1.2403 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 57/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2197 - accuracy: 0.3285 - weighted_accuracy: 0.5827 - val_loss: 1.2419 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 58/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2074 - accuracy: 0.3302 - weighted_accuracy: 0.5953 - val_loss: 1.2446 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 59/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2054 - accuracy: 0.3302 - weighted_accuracy: 0.5901 - val_loss: 1.2492 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.1250e-04
# Epoch 60/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2295 - accuracy: 0.3276 - weighted_accuracy: 0.5814 - val_loss: 1.2467 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 61/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2195 - accuracy: 0.3285 - weighted_accuracy: 0.5953 - val_loss: 1.2486 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 62/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2149 - accuracy: 0.3280 - weighted_accuracy: 0.5891 - val_loss: 1.2474 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 63/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2165 - accuracy: 0.3285 - weighted_accuracy: 0.5971 - val_loss: 1.2483 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 64/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2333 - accuracy: 0.3302 - weighted_accuracy: 0.5885 - val_loss: 1.2480 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 65/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2354 - accuracy: 0.3280 - weighted_accuracy: 0.5851 - val_loss: 1.2471 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 66/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2243 - accuracy: 0.3272 - weighted_accuracy: 0.5715 - val_loss: 1.2455 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 67/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2006 - accuracy: 0.3293 - weighted_accuracy: 0.5893 - val_loss: 1.2481 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 68/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2314 - accuracy: 0.3272 - weighted_accuracy: 0.5731 - val_loss: 1.2463 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 69/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2419 - accuracy: 0.3272 - weighted_accuracy: 0.5647 - val_loss: 1.2445 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.5625e-04
# Epoch 70/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2260 - accuracy: 0.3276 - weighted_accuracy: 0.5852 - val_loss: 1.2446 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 71/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2189 - accuracy: 0.3315 - weighted_accuracy: 0.5873 - val_loss: 1.2449 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 72/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2310 - accuracy: 0.3276 - weighted_accuracy: 0.5844 - val_loss: 1.2450 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 73/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2300 - accuracy: 0.3280 - weighted_accuracy: 0.5912 - val_loss: 1.2442 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 74/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2167 - accuracy: 0.3298 - weighted_accuracy: 0.5982 - val_loss: 1.2434 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 75/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2113 - accuracy: 0.3289 - weighted_accuracy: 0.5944 - val_loss: 1.2437 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 76/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2172 - accuracy: 0.3263 - weighted_accuracy: 0.5857 - val_loss: 1.2446 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 77/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2154 - accuracy: 0.3323 - weighted_accuracy: 0.5973 - val_loss: 1.2456 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 78/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2011 - accuracy: 0.3285 - weighted_accuracy: 0.5974 - val_loss: 1.2463 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 79/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2155 - accuracy: 0.3272 - weighted_accuracy: 0.5912 - val_loss: 1.2456 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 7.8125e-05
# Epoch 80/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2171 - accuracy: 0.3280 - weighted_accuracy: 0.5970 - val_loss: 1.2456 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 81/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2361 - accuracy: 0.3276 - weighted_accuracy: 0.5827 - val_loss: 1.2456 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 82/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2394 - accuracy: 0.3276 - weighted_accuracy: 0.5801 - val_loss: 1.2449 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 83/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2438 - accuracy: 0.3263 - weighted_accuracy: 0.5780 - val_loss: 1.2446 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 84/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2323 - accuracy: 0.3289 - weighted_accuracy: 0.5751 - val_loss: 1.2449 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 85/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2203 - accuracy: 0.3289 - weighted_accuracy: 0.5904 - val_loss: 1.2447 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 86/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.1925 - accuracy: 0.3302 - weighted_accuracy: 0.5968 - val_loss: 1.2448 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 87/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.1978 - accuracy: 0.3276 - weighted_accuracy: 0.5953 - val_loss: 1.2449 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 88/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2032 - accuracy: 0.3310 - weighted_accuracy: 0.6087 - val_loss: 1.2450 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 89/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.1972 - accuracy: 0.3289 - weighted_accuracy: 0.5952 - val_loss: 1.2451 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 3.9062e-05
# Epoch 90/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2182 - accuracy: 0.3285 - weighted_accuracy: 0.5828 - val_loss: 1.2452 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 91/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2175 - accuracy: 0.3293 - weighted_accuracy: 0.5909 - val_loss: 1.2452 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 92/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2243 - accuracy: 0.3280 - weighted_accuracy: 0.5893 - val_loss: 1.2454 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 93/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2151 - accuracy: 0.3280 - weighted_accuracy: 0.5772 - val_loss: 1.2454 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 94/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2090 - accuracy: 0.3315 - weighted_accuracy: 0.6056 - val_loss: 1.2455 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 95/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2400 - accuracy: 0.3280 - weighted_accuracy: 0.5758 - val_loss: 1.2456 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 96/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2216 - accuracy: 0.3289 - weighted_accuracy: 0.5968 - val_loss: 1.2458 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 97/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2118 - accuracy: 0.3306 - weighted_accuracy: 0.5910 - val_loss: 1.2459 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 98/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2161 - accuracy: 0.3285 - weighted_accuracy: 0.5953 - val_loss: 1.2459 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 99/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2075 - accuracy: 0.3276 - weighted_accuracy: 0.5835 - val_loss: 1.2458 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 1.9531e-05
# Epoch 100/100
# 234/234 [==============================] - 0s 2ms/step - loss: 2.2157 - accuracy: 0.3289 - weighted_accuracy: 0.5800 - val_loss: 1.2458 - val_accuracy: 0.3615 - val_weighted_accuracy: 0.6955 - lr: 9.7656e-06
# 21/21 [==============================] - 0s 2ms/step - loss: 2.4739 - accuracy: 0.3410 - weighted_accuracy: 0.5951
# Test Unweighted Accuracy: 34.10%
# Test Weighted Accuracy: 59.51%

# %%
def predict_injury_type(user_data):
    # Convert user data into DataFrame
    input_df = pd.DataFrame([user_data])
    
    # Encode user data using the same label encoders used during training
    for column in label_encoders:
        if column in input_df.columns:  # Ensure we're only encoding expected columns
            input_df[column] = label_encoders[column].transform(input_df[column])
    
    # Predict probabilities
    probabilities = model.predict(input_df)[0]
    
    # Decode the predicted probabilities back to labels
    injury_types = {index: label for index, label in enumerate(label_encoders['Type of Injury'].classes_)}
    predicted_probs = {injury_types[i]: prob for i, prob in enumerate(probabilities)}

    return predicted_probs

user_input = {
    'Gender': 'Kvinder',
    'Age': '18-24 år',
    'Area': 'Region Syddanmark',
    'Type of Vehicle': 'Taxi'
}
predicted_probabilities = predict_injury_type(user_input)

# Visualizing the probabilities
plt.bar(predicted_probabilities.keys(), predicted_probabilities.values())
plt.title('Predicted Probability of Different Injury Types')
plt.xlabel('Type of Injury')
plt.ylabel('Probability')
plt.xticks(rotation=45)
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
model_output = model.predict(user_input)
print("Raw model output:", model_output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 model_output = model.predict(user_input)
#       2 print("Raw model output:", model_output)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\src\engine\data_adapter.py:1105, in select_data_adapter(x, y)
#    1102 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1103 if not adapter_cls:
#    1104     # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1105     raise ValueError(
#    1106         "Failed to find data adapter that can handle input: {}, {}".format(
#    1107             _type_name(x), _type_name(y)
#    1108         )
#    1109     )
#    1110 elif len(adapter_cls) > 1:
#    1111     raise RuntimeError(
#    1112         "Data adapters should be mutually exclusive for "
#    1113         "handling inputs. Found multiple adapters {} to handle "
#    1114         "input: {}, {}".format(adapter_cls, _type_name(x), _type_name(y))
#    1115     )
#
# ValueError: Failed to find data adapter that can handle input: (<class 'dict'> containing {"<class 'str'>"} keys and {"<class 'str'>"} values), <class 'NoneType'>
